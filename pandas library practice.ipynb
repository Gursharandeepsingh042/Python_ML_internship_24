# %%
'''  - pandas is used in data cleaning and managaing, it also deals with import, export and manupilation of the data.
     - NUMPY is used to convert any bunch of data into array and work on the matriculation of the same data.
     - 

     - series : 1D ARRAY
     -dataframe: 2D and 3D array

# %%
import numpy as np
import pandas as pd

# %%
#create a dictionary and use panda functions on it
dic={ 
    "Name":[ "RAJU","NIGGA","DANNY","TUNTUN"],
    "ROLLNO":[1,2,3,4],   
    "Grades": ["A","b","D","A"],
    "email": ["ram@gmail.com", "nigu@gmail.com","dammu@yahoo.in","tunntunn@dholakpur.in"]
}

# %%
dic
# Out:
# {'Name': ['RAJU', 'NIGGA', 'DANNY', 'TUNTUN'],
#  'ROLLNO': [1, 2, 3, 4],
#  'Grades': ['A', 'b', 'D', 'A'],
#  'email': ['ram@gmail.com',
#   'nigu@gmail.com',
#   'dammu@yahoo.in',
#   'tunntunn@dholakpur.in']}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#      Name  ROLLNO Grades                  email
# 0    RAJU       1      A          ram@gmail.com
# 1   NIGGA       2      b         nigu@gmail.com
# 2   DANNY       3      D         dammu@yahoo.in
# 3  TUNTUN       4      A  tunntunn@dholakpur.in

# %%
df.head()
# Out:
#      Name  ROLLNO Grades                  email
# 0    RAJU       1      A          ram@gmail.com
# 1   NIGGA       2      b         nigu@gmail.com
# 2   DANNY       3      D         dammu@yahoo.in
# 3  TUNTUN       4      A  tunntunn@dholakpur.in

# %%
df.tail()
# Out:
#      Name  ROLLNO Grades                  email
# 0    RAJU       1      A          ram@gmail.com
# 1   NIGGA       2      b         nigu@gmail.com
# 2   DANNY       3      D         dammu@yahoo.in
# 3  TUNTUN       4      A  tunntunn@dholakpur.in

# %%
df.head(2)
# Out:
#     Name  ROLLNO Grades           email
# 0   RAJU       1      A   ram@gmail.com
# 1  NIGGA       2      b  nigu@gmail.com

# %%
df.tail(2)
# Out:
#      Name  ROLLNO Grades                  email
# 2   DANNY       3      D         dammu@yahoo.in
# 3  TUNTUN       4      A  tunntunn@dholakpur.in

# %%
df.describe()
# Out:
#          ROLLNO
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
df = pd.Series(dic)

# %%
df
# Out:
# Name                           [RAJU, NIGGA, DANNY, TUNTUN]
# ROLLNO                                         [1, 2, 3, 4]
# Grades                                         [A, b, D, A]
# email     [ram@gmail.com, nigu@gmail.com, dammu@yahoo.in...
# dtype: object

# %%
df=pd.DataFrame(dic)

# %%
df
# Out:
#      Name  ROLLNO Grades                  email
# 0    RAJU       1      A          ram@gmail.com
# 1   NIGGA       2      b         nigu@gmail.com
# 2   DANNY       3      D         dammu@yahoo.in
# 3  TUNTUN       4      A  tunntunn@dholakpur.in

# %%
cus=pd.read_csv("details.csv")

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus["CustomerID"])
# Out:
# pandas.core.series.Series

# %% [raw]
# cus.index

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.copy
# Out:
# <bound method NDFrame.copy of     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# ...

# %%
cus.drop(3)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.loc[(48,59),('Company Name','Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 59       Princesa Isabel Vinhoss  Isabel de Castro

# %%
cus.loc[(np.arange(48,79)),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[(np.arange(48,79)),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:,'Costumer Name']
# Out:
# 0           Maria Anders
# 1           Ana Trujillo
# 2         Antonio Moreno
# 3           Thomas Hardy
# 4     Christina Berglund
#              ...
# 86      Pirkko Koskitalo
# 87         Paula Parente
# 88        Karl Jablonski
# 89       Matti Karttunen
# 90               Zbyszek
# Name: Costumer Name, Length: 91, dtype: object

# %%
CN=cus.loc[:,'Costumer Name']
CN
# Out:
# 0           Maria Anders
# 1           Ana Trujillo
# 2         Antonio Moreno
# 3           Thomas Hardy
# 4     Christina Berglund
#              ...
# 86      Pirkko Koskitalo
# 87         Paula Parente
# 88        Karl Jablonski
# 89       Matti Karttunen
# 90               Zbyszek
# Name: Costumer Name, Length: 91, dtype: object

# %%
CN.drop_duplicates()
# Out:
# 0           Maria Anders
# 1           Ana Trujillo
# 2         Antonio Moreno
# 3           Thomas Hardy
# 4     Christina Berglund
#              ...
# 86      Pirkko Koskitalo
# 87         Paula Parente
# 88        Karl Jablonski
# 89       Matti Karttunen
# 90               Zbyszek
# Name: Costumer Name, Length: 91, dtype: object

# %%
employees = [
    {"company_name": "TechCorp", "job_role": "Software Engineer", "employee_name": "Alice Johnson"},
    {"company_name": "HealthPlus", "job_role": "Data Analyst", "employee_name": "Bob Smith"},
    {"company_name": "EduWorld", "job_role": "Teacher", "employee_name": "Carol White"},
    {"company_name": "BuildIt", "job_role": "Construction Manager", "employee_name": "David Brown"},
    {"company_name": "Foodies", "job_role": "Chef", "employee_name": "Emma Davis"},
    {"company_name": "DesignPro", "job_role": "Graphic Designer", "employee_name": "Frank Miller"},
    {"company_name": "MarketMakers", "job_role": "Marketing Specialist", "employee_name": "Grace Wilson"},
    {"company_name": "SecureSafe", "job_role": "Cybersecurity Analyst", "employee_name": "Henry Moore"},
    {"company_name": "GreenFuture", "job_role": "Environmental Engineer", "employee_name": "Ivy Taylor"},
    {"company_name": "RetailHub", "job_role": "Store Manager", "employee_name": "Jack Anderson"},
    {"company_name": "AutoWorks", "job_role": "Mechanical Engineer", "employee_name": "Kathy Thompson"},
    {"company_name": "HealthPlus", "job_role": "Nurse", "employee_name": "Liam Martinez"},
    {"company_name": "TechCorp", "job_role": "Product Manager", "employee_name": "Mia Jackson"},
    {"company_name": "BuildIt", "job_role": "Civil Engineer", "employee_name": "Nathan Harris"},
    {"company_name": "EduWorld", "job_role": "Principal", "employee_name": "Olivia Clark"},
    {"company_name": "MarketMakers", "job_role": "SEO Specialist", "employee_name": "Paul Lewis"},
    {"company_name": "DesignPro", "job_role": "UI/UX Designer", "employee_name": "Quinn Young"},
    {"company_name": "SecureSafe", "job_role": "Network Engineer", "employee_name": "Ryan Walker"},
    {"company_name": "GreenFuture", "job_role": "Renewable Energy Consultant", "employee_name": "Sophia Hall"},
    {"company_name": "RetailHub", "job_role": "Cashier", "employee_name": "Tom King"},
    {"company_name": "Foodies", "job_role": "Restaurant Manager", "employee_name": "Uma Scott"},
    {"company_name": "AutoWorks", "job_role": "Auto Mechanic", "employee_name": "Victor Wright"},
    {"company_name": "TechCorp", "job_role": "DevOps Engineer", "employee_name": "Wendy Lopez"},
    {"company_name": "HealthPlus", "job_role": "Pharmacist", "employee_name": "Xander Hill"},
    {"company_name": "EduWorld", "job_role": "Counselor", "employee_name": "Yara Adams"},
    {"company_name": "BuildIt", "job_role": "Architect", "employee_name": "Zachary Baker"},
    {"company_name": "Foodies", "job_role": "Pastry Chef", "employee_name": "Amanda Gonzales"},
    {"company_name": "DesignPro", "job_role": "Art Director", "employee_name": "Brian Carter"},
    {"company_name": "MarketMakers", "job_role": "Content Writer", "employee_name": "Chloe Mitchell"},
    {"company_name": "SecureSafe", "job_role": "IT Support Specialist", "employee_name": "Dylan Perez"},
    {"company_name": "GreenFuture", "job_role": "Sustainability Consultant", "employee_name": "Ella Roberts"},
    {"company_name": "RetailHub", "job_role": "Sales Associate", "employee_name": "Finn Edwards"},
    {"company_name": "AutoWorks", "job_role": "Quality Control Inspector", "employee_name": "Gabby Ward"},
    {"company_name": "TechCorp", "job_role": "Software Tester", "employee_name": "Hank Baker"},
    {"company_name": "HealthPlus", "job_role": "Physical Therapist", "employee_name": "Isla Turner"},
    {"company_name": "EduWorld", "job_role": "Librarian", "employee_name": "Jake Torres"},
    {"company_name": "BuildIt", "job_role": "Surveyor", "employee_name": "Kara Phillips"},
    {"company_name": "Foodies", "job_role": "Sous Chef", "employee_name": "Leo Campbell"},
    {"company_name": "DesignPro", "job_role": "Interior Designer", "employee_name": "Mila Parker"},
    {"company_name": "MarketMakers", "job_role": "Social Media Manager", "employee_name": "Noah Flores"},
    {"company_name": "SecureSafe", "job_role": "Security Consultant", "employee_name": "Olive Bennett"},
    {"company_name": "GreenFuture", "job_role": "Environmental Scientist", "employee_name": "Pete Sanchez"},
    {"company_name": "RetailHub", "job_role": "Customer Service Representative", "employee_name": "Quincy Morgan"},
    {"company_name": "AutoWorks", "job_role": "Parts Specialist", "employee_name": "Riley Peterson"},
    {"company_name": "TechCorp", "job_role": "Systems Analyst", "employee_name": "Sara Cooper"},
    {"company_name": "HealthPlus", "job_role": "Lab Technician", "employee_name": "Timothy Reed"},
    {"company_name": "EduWorld", "job_role": "Janitor", "employee_name": "Uma Sanders"},
    {"company_name": "BuildIt", "job_role": "Project Manager", "employee_name": "Victor Ross"},
    {"company_name": "Foodies", "job_role": "Line Cook", "employee_name": "Wendy Russell"}
]

employees
# Out:
# [{'company_name': 'TechCorp',
#   'job_role': 'Software Engineer',
#   'employee_name': 'Alice Johnson'},
#  {'company_name': 'HealthPlus',
#   'job_role': 'Data Analyst',
#   'employee_name': 'Bob Smith'},
#  {'company_name': 'EduWorld',
#   'job_role': 'Teacher',
#   'employee_name': 'Carol White'},
#  {'company_name': 'BuildIt',
#   'job_role': 'Construction Manager',
#   'employee_name': 'David Brown'},
#  {'company_name': 'Foodies',
#   'job_role': 'Chef',
#   'employee_name': 'Emma Davis'},
#  {'company_name': 'DesignPro',
#   'job_role': 'Graphic Designer',
#   'employee_name': 'Frank Miller'},
#  {'company_name': 'MarketMakers',
#   'job_role': 'Marketing Specialist',
#   'employee_name': 'Grace Wilson'},
#  {'company_name': 'SecureSafe',
#   'job_role': 'Cybersecurity Analyst',
#   'employee_name': 'Henry Moore'},
#  {'company_name': 'GreenFuture',
#   'job_role': 'Environmental Engineer',
#   'employee_name': 'Ivy Taylor'},
#  {'company_name': 'RetailHub',
# ...

# %%
cd = pd.DataFrame(employees)

# %%
cd.T
# Out:
#                               0             1            2   \
# company_name            TechCorp    HealthPlus     EduWorld
# job_role       Software Engineer  Data Analyst      Teacher
# employee_name      Alice Johnson     Bob Smith  Carol White
#
#                                  3           4                 5   \
# company_name                BuildIt     Foodies         DesignPro
# job_role       Construction Manager        Chef  Graphic Designer
# employee_name           David Brown  Emma Davis      Frank Miller
#
#                                  6                      7   \
# company_name           MarketMakers             SecureSafe
# job_role       Marketing Specialist  Cybersecurity Analyst
# employee_name          Grace Wilson            Henry Moore
#
#                                    8              9   ...  \
# company_name              GreenFuture      RetailHub  ...
# job_role       Environmental Engineer  Store Manager  ...
# ...

# %%
cd.drop_duplicates(subset='company_name',keep= 'last')
# Out:
#     company_name                         job_role   employee_name
# 38     DesignPro                Interior Designer     Mila Parker
# 39  MarketMakers             Social Media Manager     Noah Flores
# 40    SecureSafe              Security Consultant   Olive Bennett
# 41   GreenFuture          Environmental Scientist    Pete Sanchez
# 42     RetailHub  Customer Service Representative   Quincy Morgan
# 43     AutoWorks                 Parts Specialist  Riley Peterson
# 44      TechCorp                  Systems Analyst     Sara Cooper
# 45    HealthPlus                   Lab Technician    Timothy Reed
# 46      EduWorld                          Janitor     Uma Sanders
# 47       BuildIt                  Project Manager     Victor Ross
# 48       Foodies                        Line Cook   Wendy Russell

# %%
cd.drop_duplicates(subset= 'job_role',keep=False)
# Out:
#     company_name                         job_role    employee_name
# 0       TechCorp                Software Engineer    Alice Johnson
# 1     HealthPlus                     Data Analyst        Bob Smith
# 2       EduWorld                          Teacher      Carol White
# 3        BuildIt             Construction Manager      David Brown
# 4        Foodies                             Chef       Emma Davis
# 5      DesignPro                 Graphic Designer     Frank Miller
# 6   MarketMakers             Marketing Specialist     Grace Wilson
# 7     SecureSafe            Cybersecurity Analyst      Henry Moore
# 8    GreenFuture           Environmental Engineer       Ivy Taylor
# 9      RetailHub                    Store Manager    Jack Anderson
# 10     AutoWorks              Mechanical Engineer   Kathy Thompson
# 11    HealthPlus                            Nurse    Liam Martinez
# 12      TechCorp                  Product Manager      Mia Jackson
# ...

# %%
cd.drop_duplicates(subset= "job_role",keep="first")
# Out:
#     company_name                         job_role    employee_name
# 0       TechCorp                Software Engineer    Alice Johnson
# 1     HealthPlus                     Data Analyst        Bob Smith
# 2       EduWorld                          Teacher      Carol White
# 3        BuildIt             Construction Manager      David Brown
# 4        Foodies                             Chef       Emma Davis
# 5      DesignPro                 Graphic Designer     Frank Miller
# 6   MarketMakers             Marketing Specialist     Grace Wilson
# 7     SecureSafe            Cybersecurity Analyst      Henry Moore
# 8    GreenFuture           Environmental Engineer       Ivy Taylor
# 9      RetailHub                    Store Manager    Jack Anderson
# 10     AutoWorks              Mechanical Engineer   Kathy Thompson
# 11    HealthPlus                            Nurse    Liam Martinez
# 12      TechCorp                  Product Manager      Mia Jackson
# ...

# %%
cd.to_csv("data.csv", index= False)

# %%
'''     libraries to handle excel files in pandas ::     To read: xlrd     and    To write:openpyxl   '''
# Out:
# '     libraries to handle excel files in pandas ::     To read: xlrd     and    To write:openpyxl   '

# %%
com_dat= pd.read_csv('data.csv')

# %%
com_dat
# Out:
#     company_name                         job_role    employee_name
# 0       TechCorp                Software Engineer    Alice Johnson
# 1     HealthPlus                     Data Analyst        Bob Smith
# 2       EduWorld                          Teacher      Carol White
# 3        BuildIt             Construction Manager      David Brown
# 4        Foodies                             Chef       Emma Davis
# 5      DesignPro                 Graphic Designer     Frank Miller
# 6   MarketMakers             Marketing Specialist     Grace Wilson
# 7     SecureSafe            Cybersecurity Analyst      Henry Moore
# 8    GreenFuture           Environmental Engineer       Ivy Taylor
# 9      RetailHub                    Store Manager    Jack Anderson
# 10     AutoWorks              Mechanical Engineer   Kathy Thompson
# 11    HealthPlus                            Nurse    Liam Martinez
# 12      TechCorp                  Product Manager      Mia Jackson
# ...

# %%
com_dat.drop(2,axis=0)
# Out:
#     company_name                         job_role    employee_name
# 0       TechCorp                Software Engineer    Alice Johnson
# 1     HealthPlus                     Data Analyst        Bob Smith
# 3        BuildIt             Construction Manager      David Brown
# 4        Foodies                             Chef       Emma Davis
# 5      DesignPro                 Graphic Designer     Frank Miller
# 6   MarketMakers             Marketing Specialist     Grace Wilson
# 7     SecureSafe            Cybersecurity Analyst      Henry Moore
# 8    GreenFuture           Environmental Engineer       Ivy Taylor
# 9      RetailHub                    Store Manager    Jack Anderson
# 10     AutoWorks              Mechanical Engineer   Kathy Thompson
# 11    HealthPlus                            Nurse    Liam Martinez
# 12      TechCorp                  Product Manager      Mia Jackson
# 13       BuildIt                   Civil Engineer    Nathan Harris
# ...
