# %%
import numpy as np
import pandas as pd
from  matplotlib import pyplot as plt

# %%
sm=pd.read_csv('student_marks.csv')
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
# [559 rows x 7 columns]

# %%
sm['Total']= sm[['English','Hindi'	,'Maths','Science','SST']].sum(axis=1)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      total  Total
# 0      306    306
# 1      365    365
# 2      155    155
# 3      257    257
# 4      181    181
# ..     ...    ...
# 554    358    358
# 555     86     86
# 556    113    113
# 557    423    423
# 558    398    398
#
# [559 rows x 9 columns]

# %%
sm['Percentage']= sm[['Total']]/5
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      total  Total  Percentage
# 0      306    306        61.2
# 1      365    365        73.0
# 2      155    155        31.0
# 3      257    257        51.4
# 4      181    181        36.2
# ..     ...    ...         ...
# 554    358    358        71.6
# 555     86     86        17.2
# 556    113    113        22.6
# 557    423    423        84.6
# 558    398    398        79.6
#
# [559 rows x 10 columns]

# %%
#calculate the grades

def calc_grade(p):
    if p<=100 and p>=80:
        return 'A'
    elif p<80 and p>=60:
        return'B'
    elif p<60 and p>=50:
        return'C'
    elif p<50 and p>=40:
        return'D'
    elif p<40 and p>=30:
        return'E'
    elif p<30 and p>=0:
        return'F'
    else:
        return'xx'


sm['Grades']=sm['Percentage'].apply(calc_grade)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      total  Total  Percentage Grades
# 0      306    306        61.2      B
# 1      365    365        73.0      B
# 2      155    155        31.0      E
# 3      257    257        51.4      C
# 4      181    181        36.2      E
# ..     ...    ...         ...    ...
# 554    358    358        71.6      B
# 555     86     86        17.2      F
# 556    113    113        22.6      F
# 557    423    423        84.6      A
# 558    398    398        79.6      B
#
# [559 rows x 11 columns]

# %%
temp=sm.head()
plt.figure(figsize=(10,6))
for sub in ['English','Hindi','Maths','Science','SST']:
  plt.plot(temp['Name'],temp[sub],marker='o',label=sub)
  plt.title("Marks in different subjects")
  plt.xlabel("Name        ")
  plt.ylabel("Marks")
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
sub=['English','Hindi','Maths','Science','SST']
col=['b','r','g','y','m']

for sub in range(5): 
  plt.figure(figsize=(10,6))
  plt.plot(temp['Name'],temp[sub],marker='o',color= col['i'],label=sub)
  plt.title("Marks in different subjects")
  plt.xlabel("Name")
  plt.ylabel("Marks")
  plt.legend()
  plt.grid(True)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 col=['b','r','g','y','m']
#       4 for sub in range(5):
# ----> 5   plt.figure(figsize=(10,6))
#       6   plt.plot(temp['Name'],temp[sub],marker='o',color= col['i'],label=sub)
#       7   plt.title("Marks in different subjects")
#
# NameError: name 'plt' is not defined

# %%
sub=['English','Hindi','Maths','Science','SST']
plt.figure(figsize=(10,5))

plt.plot(temp['Name'],temp[sub],marker='o',label=sub)
plt.title("Marks in different subjects")
plt.xlabel("Name        ")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Number of rows
rows = 5

# Iterating value for column
k = 2*rows-2

# Loop through rows
for i in range(rows):
    
    # Loop to print initial spaces
    for j in range(k):
        print(end=" ")
    
    # Updating value of K
    k = k-2
    
    # Loop to print the stars
    for j in range(i+1):
        print("*", end=" ")
    print()
